# %%
print(2 + 3)

print(5 - 2)

print(5 * 2)

print(10 / 3)

print(10 // 3)

print(30 % 4)

print(5 ** 2)
# Out:
# 5
# 3
# 10
# 3.3333333333333335
# 3
# 2
# 25

# %%
# Stages 1-Analysis 2-Design 3-Implementation 4-Testing 

stage = int(input("What phase you are in (1-4)?"))

print(stage)
# Out:
# What phase you are in (1-4)? 3
# 3

# %%
name = 'Maheswaran'

salary = 200000

age = 47

is_active = True

print('Name:', name)
print('Age:', age)
print('Salary:', salary)
print('Status:', is_active)
# Out:
# Name: Maheswaran
# Age: 47
# Salary: 200000
# Status: True

# %%
name = input('Name:')

salary = float(input('Salary:'))

age = int(input('Age:'))

is_active = int(input('Status(1-Active, 2-Inactive):')) == 1

print('Name:', name)
print('Age:', age)
print('Salary:', salary)
print('Status:', is_active)
# Out:
# Name: K L Rahul
# Salary: 450000
# Age: 35
# Status(1-Active, 2-Inactive): 2
# Name: K L Rahul
# Age: 35
# Salary: 450000.0
# Status: False

# %%
# list
salaries = [500000, 250000, 300000, 275000, 800000] 

print(salaries)

print(type(salaries))
# Out:
# [500000, 250000, 300000, 275000, 800000]
# <class 'list'>

# %%
jaiswal = ['Jaiswal', 23, 300000, True] # employee row is as list 
suryawancy = ['Suryawancy', 14, 250000, True]

employees = [jaiswal, suryawancy]
print(employees)
# Out:
# [['Jaiswal', 23, 300000, True], ['Suryawancy', 14, 250000, True]]

# %%
jaiswal = ('Jaiswal', 23, 300000, True) # employee row is as tuple 
suryawancy = ('Suryawancy', 14, 250000, True)

employees = [jaiswal, suryawancy]
print(employees)
# Out:
# [('Jaiswal', 23, 300000, True), ('Suryawancy', 14, 250000, True)]

# %%
jaiswal = {'name': 'Jaiswal', 'age':23, 'salary':300000, 'is_active':True} # employee row is as dict 
suryawancy = {'name': 'Suryawancy','age':14, 'salary':250000, 'is_active':True}

employees = [jaiswal, suryawancy]
print(employees)
# Out:
# [{'name': 'Jaiswal', 'age': 23, 'salary': 300000, 'is_active': True}, {'name': 'Suryawancy', 'age': 14, 'salary': 250000, 'is_active': True}]

# %%
freq = {}
type(freq)
# Out:
# dict
