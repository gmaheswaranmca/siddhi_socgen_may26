# %%
ages = []

# %%
ages.append(10)
ages.append(20)
ages.append(30)
ages.append(3)

# %%
ages
# Out:
# [10, 20, 30, 3]

# %%
ages.remove(20)

# %%
ages
# Out:
# [10, 30, 3]

# %%
ages[1] = 33

# %%
ages
# Out:
# [10, 33, 3]
