# %%
import repo_list_list as repo
repo.create_emp(['Mahesh', 47])
print(repo.read_all())
repo.create_emp(['Aparna', 27])
print(repo.read_all())
print(repo.read_by_name('Aparna'))
repo.create_emp(['Aniruth', 23])
print(repo.read_all())
repo.update_by_name('Aniruth', 30)
print(repo.read_all())
repo.delete_by_name('Mahesh')
print(repo.read_all())
# Out:
# [['Mahesh', 47]]
# [['Mahesh', 47], ['Aparna', 27]]
# ['Aparna', 27]
# [['Mahesh', 47], ['Aparna', 27], ['Aniruth', 23]]
# [['Mahesh', 47], ['Aparna', 27], ['Aniruth', 30]]
# [['Aparna', 27], ['Aniruth', 30]]
