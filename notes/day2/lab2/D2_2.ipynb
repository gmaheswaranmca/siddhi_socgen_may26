# %%
import sys

print(sys.version) # Python version 
print(sys.path) # Module search path
print(sys.argv) # Command line arguments
# Out:
# 3.12.1 (tags/v3.12.1:2305ca5, Dec  7 2023, 22:03:25) [MSC v.1937 64 bit (AMD64)]
# ['d:\\2C\\mywork2603\\source\\livapp_z5001\\z5001\\001\\day_nb\\Day02\\lab2', 'c:\\Users\\gmahe\\AppData\\Local\\Programs\\Python\\Python312\\python312.zip', 'c:\\Users\\gmahe\\AppData\\Local\\Programs\\Python\\Python312\\DLLs', 'c:\\Users\\gmahe\\AppData\\Local\\Programs\\Python\\Python312\\Lib', 'c:\\Users\\gmahe\\AppData\\Local\\Programs\\Python\\Python312', '', 'C:\\Users\\gmahe\\AppData\\Roaming\\Python\\Python312\\site-packages', 'C:\\Users\\gmahe\\AppData\\Roaming\\Python\\Python312\\site-packages\\win32', 'C:\\Users\\gmahe\\AppData\\Roaming\\Python\\Python312\\site-packages\\win32\\lib', 'C:\\Users\\gmahe\\AppData\\Roaming\\Python\\Python312\\site-packages\\Pythonwin', 'c:\\Users\\gmahe\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages']
# ...

# %%
print("Start")

sys.exit() # Exit program

print("End")
# Out:
# Start
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\Users\gmahe\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py:3561: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
import calc 

print(calc.find_sum(15, 10))
print(calc.find_diff(15, 10))
# Out:
# 25
# 5

# %%
import calc as mycalc

print(mycalc.find_sum(15, 10))
print(mycalc.find_diff(15, 10))
# Out:
# 25
# 5

# %%
from calc import find_sum 

print(find_sum(15, 10))
# print(find_diff(15, 10)) # err you will get
# Out:
# 25

# %%
from calc import find_sum as calc_sum 

print(calc_sum(15, 10))
# Out:
# 25
