# %%
import calc_v2

# accessing doc string 

print(calc_v2.__doc__)
# Out:
# calc.py
#
# A simple calculator utility module.
#
# This module provides basic arithmetic operations such as:
# - addition
# - subtraction
#
# Functions:
#     find_sum(num1, num2)
#         Returns the sum of two numbers.
#
#     find_diff(num1, num2)
#         Returns the difference between two numbers.

# %%
print(calc_v2.find_sum.__doc__)
# Out:
#     Returns the sum of two numbers.
#
#     Parameters:
#         num1 : int or float
#             The first number.
#         num2 : int or float
#             The second number.
#
#     Returns:
#         int or float
#             The sum of num1 and num2.
#
#     Example:
#         >>> find_sum(10, 20)
#         30

# %%
print(calc_v2.find_diff.__doc__)
# Out:
#     Returns the difference between two numbers.
#
#     Parameters:
#         num1 : int or float
#             The first number.
#         num2 : int or float
#             The second number.
#
#     Returns:
#         int or float
#             The difference obtained by subtracting
#             num2 from num1.
#
#     Example:
#         >>> find_diff(20, 5)
#         15
